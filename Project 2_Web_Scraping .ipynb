# %% [markdown]
# # Project 2: Web Scraping 1 of 2
#
# Name: Vanessa Hu
# Date: September 29, 2020
#
# Weeks 2 and 3
# Backstory:
# Using information we scrape from the web, build linear regression models from which we can learn about movies, sports, or categories.
#
# Data:
# acquisition: web scraping
# storage: flat files
# sources: (as listed below or any other publicly available information)
# movie: boxofficemojo.com, imdb.com
# sports: sports-reference.com
# Skills:
# basics of the web (requests, HTML, CSS, JavaScript)
#
# web scraping
# numpy and pandas
# statsmodels, scikit-learn
# Analysis:
# linear regression is required, other regression methods are optional
# Deliverable/communication:
# organized project repository
# slide presentation
# visual and oral communication in presentations
# write-up of process and results
#
#
# Design:
# iterative design process
# "MVP"s and building outward
# stand-ups/scrums (1 minute progress updates to the class)
#
# More information:
# We'll learn about web scraping using two popular tools - BeautifulSoup and Selenium. You must know the very basics of HTML. We can also evolve the way we use Jupyter notebooks; during this project, we begin to use the notebook as a development scratchpad, where we test things out through interactive scripting, but then solidify our work in python modules with reusable functions and classes.
#
# We'll practice using linear regression. We'll have a first taste of feature selection, this time based on our intuition and some trial and error, and we'll build and refine our models.
#
# This project will give you the freedom to challenge yourself, no matter your skill level. Find your boundaries and push them a little further. We are very excited to see what you will learn and do for Project Luther!

# %% [markdown]
# ## Setting up and Testing for Web Scraping

# %%
from bs4 import BeautifulSoup
import requests
import csv 
import pandas as pd 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Try if the website allows web scrapting
Url = "https://finance.yahoo.com/quote/ATOM/financials?p=ATOM"
r=requests.get(Url)
r.status_code
# Out:
# 200

# %%
# It seems "simpTblRow" is a key word to navigate

Url = "https://finance.yahoo.com/most-active?offset=2&amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;count=100"
r= requests.get(Url)
data=r.text
soup=BeautifulSoup(data,'lxml')

names=[]

for item in soup.select('.simpTblRow'):
    try:
        print(item)
        print('------------------')
    except Exception as e:
        raise e
        print('')
# Out:
# <tr class="simpTblRow Bgc($hoverBgColor):h BdB Bdbc($seperatorColor) Bdbc($tableBorderBlue):h H(32px) Bgc($lv2BgColor)" data-reactid="73"><td aria-label="Symbol" class="Va(m) Ta(start) Pstart(6px) Pend(10px) Miw(90px) Start(0) Pend(10px) simpTblRow:h_Bgc($hoverBgColor) Pos(st) Bgc($lv3BgColor) Bgc($lv2BgColor) Ta(start)! Fz(s)" colspan="" data-reactid="74"><label class="Ta(c) Pos(r) Va(tb) Pend(5px) D(n)--print" data-reactid="75"><input class="Pos(a) V(h)" data-reactid="76" type="checkbox"/><svg class="Va(m)! H(16px) W(16px) Stk($plusGray)! Fill($plusGray)! Cur(p)" data-icon="checkbox-unchecked" data-reactid="77" height="16" style="fill:#000;stroke:#000;stroke-width:0;vertical-align:bottom;" viewbox="0 0 24 24" width="16"><path d="M3 3h18v18H3V3zm19-2H2c-.553 0-1 .448-1 1v20c0 .552.447 1 1 1h20c.552 0 1-.448 1-1V2c0-.552-.448-1-1-1z" data-reactid="78"></path></svg></label><a class="Fw(600) C($linkColor)" data-reactid="79" href="/quote/SRNE?p=SRNE" title="Sorrento Therapeutics, Inc.">
# ...

# %%
# Test the first element in the table

for item in soup.select('.simpTblRow'):

    print(item.select('[aria-label=Symbol]')[0].get_text())
    print('____________________________')
# Out:
# SRNE
# ____________________________
# GE
# ____________________________
# AMD
# ____________________________
# TSLA
# ____________________________
# AAL
# ____________________________
# PTON
# ____________________________
# BAC
# ____________________________
# F
# ____________________________
# WFC
# ____________________________
# ABEV
# ____________________________
# DKNG
# ____________________________
# SPCE
# ____________________________
# NKLA
# ____________________________
# OXY
# ____________________________
# VALE
# ____________________________
# WPX
# ____________________________
# T
# ____________________________
# MU
# ____________________________
# DVN
# ____________________________
# NOK
# ____________________________
# UAL
# ____________________________
# PBR
# ____________________________
# WKHS
# ____________________________
# CZR
# ____________________________
# MRO
# ____________________________

# %%
# Make sure all the features can also work out

Url = "https://finance.yahoo.com/most-active"
r= requests.get(Url)
data=r.text
soup=BeautifulSoup(data)


for item in soup.select('.simpTblRow'):
    print(item.select('[aria-label=Symbol]')[0].get_text())
    print(item.select('[aria-label=Name]')[0].get_text())
    print(item.select('[aria-label*=Price]')[0].get_text())
    print(item.select('[aria-label=Change]')[0].get_text())
    print(item.select('[aria-label="% Change"]')[0].get_text())
    print(item.select('[aria-label*="Volume"]')[0].get_text())
    print(item.select('[aria-label*="Avg Vol (3 month)"]')[0].get_text())
    print(item.select('[aria-label="Market Cap"]')[0].get_text())
    print(item.select('[aria-label*="52 Week Range"]')[0].get_text())
    print('____________________________')
# Out:
# NIO
# NIO Limited
# 20.85
# +2.04
# +10.85%
# 161.743M
# 133.108M
# 25.492B
#
# ____________________________
# AAPL
# Apple Inc.
# 114.09
# -0.87
# -0.76%
# 100.061M
# 171.964M
# 1.951T
#
# ____________________________
# SRNE
# Sorrento Therapeutics, Inc.
# 11.60
# +1.45
# +14.29%
# 75.865M
# 42.292M
# 2.959B
#
# ____________________________
# GE
# General Electric Company
# 6.12
# -0.08
# -1.29%
# 72.919M
# 89.104M
# 53.57B
#
# ____________________________
# AMD
# Advanced Micro Devices, Inc.
# 81.77
# +2.29
# +2.88%
# 61.634M
# 61.436M
# 96.003B
#
# ____________________________
# TSLA
# Tesla, Inc.
# 419.07
# -2.13
# -0.51%
# 50.341M
# 81.553M
# 390.493B
#
# ____________________________
# AAL
# American Airlines Group Inc.
# 12.25
# -0.51
# -4.00%
# 47.21M
# 68.757M
# 6.23B
#
# ____________________________
# PTON
# Peloton Interactive, Inc.
# 100.47
# +3.56
# +3.67%
# 41.271M
# 16.573M
# 29.005B
#
# ____________________________
# BAC
# Bank of America Corporation
# 23.77
# -0.32
# ...

# %% [markdown]
# ## Compile Stock Lists

# %% [markdown]
# ### Most Active Stocks

# %%
# Putting it together in a dictionary - Most Active Stocks

symbol=[]
names=[]
prices=[]
changes=[]
percent_changes=[]
total_volumes=[]
average_volumes=[]
market_caps=[]

 
for i in range(30,41):
    Url = "https://finance.yahoo.com/most-active?offset="+str(i)+"&amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;count=100"
    r= requests.get(Url)
    data=r.text
    soup=BeautifulSoup(data)
 
    for item in soup.select('.simpTblRow'):        
        symbol.append(item.select('[aria-label=Symbol]')[0].get_text())
        
        names.append(item.select('[aria-label=Name]')[0].get_text())
        
        prices.append(item.select('[aria-label*=Price]')[0].get_text())
        
        changes.append(item.select('[aria-label=Change]')[0].get_text())
        
        percent_changes.append(item.select('[aria-label="% Change"]')[0].get_text())               
        
        total_volumes.append(item.select('[aria-label*="Volume"]')[0].get_text())
        
        average_volumes.append(item.select('[aria-label*="Avg Vol (3 month)"]')[0].get_text())
        
        market_caps.append(item.select('[aria-label="Market Cap"]')[0].get_text())


most_active_40 = pd.DataFrame({"symbol": symbol, "names": names, "prices": prices, 
              "change": changes, "percent_changes": percent_changes,  
              "total_volumes": total_volumes,"average_volumes":average_volumes,
              "market_caps": market_caps})

# %%
#df_raw = pd.DataFrame({"symbol": symbol, "names": names, "prices": prices, 
#              "change": changes, "percent_changes": percent_changes,  
#              "total_volumes": total_volumes,"average_volumes":average_volumes,
#              "market_caps": market_caps})

# %%
most_active_10.head()
# Out:
#   symbol                         names  prices change percent_changes  \
# 0    NIO                   NIO Limited   20.85  +2.04         +10.85%
# 1   AAPL                    Apple Inc.  114.09  -0.87          -0.76%
# 2   SRNE   Sorrento Therapeutics, Inc.   11.60  +1.45         +14.29%
# 3     GE      General Electric Company    6.12  -0.08          -1.29%
# 4    AMD  Advanced Micro Devices, Inc.   81.77  +2.29          +2.88%
#
#   total_volumes average_volumes market_caps
# 0      161.743M        133.108M     25.492B
# 1      100.061M        171.964M      1.951T
# 2       75.865M         42.292M      2.959B
# 3       72.919M          89.11M      53.57B
# 4       61.634M         61.436M     96.003B

# %%
most_active_10.shape
# Out:
# (275, 8)

# %%
# Concat Most Active Stocks Together
most_active = pd.concat([most_active_10,most_active_30,most_active_40])
most_active.shape
# Out:
# (1025, 8)

# %%
# Putting it together in a dictionary - Most Active Stocks

symbol=[]
names=[]
prices=[]
changes=[]
percent_changes=[]
total_volumes=[]
average_volumes=[]
market_caps=[]

 
for i in range(0,41):
    Url = "https://finance.yahoo.com/most-active?offset="+str(i)+"&amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;count=100"
    r= requests.get(Url)
    data=r.text
    soup=BeautifulSoup(data)
 
    for item in soup.select('.simpTblRow'):        
        symbol.append(item.select('[aria-label=Symbol]')[0].get_text())
        
        names.append(item.select('[aria-label=Name]')[0].get_text())
        
        prices.append(item.select('[aria-label*=Price]')[0].get_text())
        
        changes.append(item.select('[aria-label=Change]')[0].get_text())
        
        percent_changes.append(item.select('[aria-label="% Change"]')[0].get_text())               
        
        total_volumes.append(item.select('[aria-label*="Volume"]')[0].get_text())
        
        average_volumes.append(item.select('[aria-label*="Avg Vol (3 month)"]')[0].get_text())
        
        market_caps.append(item.select('[aria-label="Market Cap"]')[0].get_text())


most_active_after = pd.DataFrame({"symbol": symbol, "names": names, "prices": prices, 
              "change": changes, "percent_changes": percent_changes,  
              "total_volumes": total_volumes,"average_volumes":average_volumes,
              "market_caps": market_caps})

# %%
most_active_after.shape
# Out:
# (1025, 8)

# %% [markdown]
# ### Top Gainers

# %%
# Top Gainers

symbol=[]
names=[]
prices=[]
changes=[]
percent_changes=[]
total_volumes=[]
average_volumes=[]
market_caps=[]

 
for i in range(0,41):
    Url = "https://finance.yahoo.com/gainers?offset="+str(i)+"&amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;count=100"
    r= requests.get(Url)
    data=r.text
    soup=BeautifulSoup(data)
 
    for item in soup.select('.simpTblRow'):        
        symbol.append(item.select('[aria-label=Symbol]')[0].get_text())
        
        names.append(item.select('[aria-label=Name]')[0].get_text())
        
        prices.append(item.select('[aria-label*=Price]')[0].get_text())
        
        changes.append(item.select('[aria-label=Change]')[0].get_text())
        
        percent_changes.append(item.select('[aria-label="% Change"]')[0].get_text())               
        
        total_volumes.append(item.select('[aria-label*="Volume"]')[0].get_text())
        
        average_volumes.append(item.select('[aria-label*="Avg Vol (3 month)"]')[0].get_text())
        
        market_caps.append(item.select('[aria-label="Market Cap"]')[0].get_text())


top_gainers = pd.DataFrame({"symbol": symbol, "names": names, "prices": prices, 
              "change": changes, "percent_changes": percent_changes,  
              "total_volumes": total_volumes,"average_volumes":average_volumes,
              "market_caps": market_caps})

# %%
# Top Gainers

symbol=[]
names=[]
prices=[]
changes=[]
percent_changes=[]
total_volumes=[]
average_volumes=[]
market_caps=[]

 
for i in range(0,41):
    Url = "https://finance.yahoo.com/gainers?offset="+str(i)+"&amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;count=100"
    r= requests.get(Url)
    data=r.text
    soup=BeautifulSoup(data)
 
    for item in soup.select('.simpTblRow'):        
        symbol.append(item.select('[aria-label=Symbol]')[0].get_text())
        
        names.append(item.select('[aria-label=Name]')[0].get_text())
        
        prices.append(item.select('[aria-label*=Price]')[0].get_text())
        
        changes.append(item.select('[aria-label=Change]')[0].get_text())
        
        percent_changes.append(item.select('[aria-label="% Change"]')[0].get_text())               
        
        total_volumes.append(item.select('[aria-label*="Volume"]')[0].get_text())
        
        average_volumes.append(item.select('[aria-label*="Avg Vol (3 month)"]')[0].get_text())
        
        market_caps.append(item.select('[aria-label="Market Cap"]')[0].get_text())


top_gainers_after = pd.DataFrame({"symbol": symbol, "names": names, "prices": prices, 
              "change": changes, "percent_changes": percent_changes,  
              "total_volumes": total_volumes,"average_volumes":average_volumes,
              "market_caps": market_caps})

# %%
top_gainers.shape
# Out:
# (1025, 8)

# %%
top_gainers.tail()
# Out:
#      symbol                       names  prices change percent_changes  \
# 1020   CWEN       Clearway Energy, Inc.   25.77  +0.89          +3.58%
# 1021  KPELY  Keppel Corporation Limited    6.31  +0.22          +3.56%
# 1022   SNOW              Snowflake Inc.  259.13  +8.72          +3.48%
# 1023   VNET        21Vianet Group, Inc.   22.77  +0.76          +3.45%
# 1024   SWCH                Switch, Inc.   16.01  +0.53          +3.42%
#
#      total_volumes average_volumes market_caps
# 1020       488,830         541,237      4.928B
# 1021        28,795          15,812      5.742B
# 1022        5.267M          9.089M     71.909B
# 1023       862,047          1.645M      2.582B
# 1024        2.528M          1.556M      3.852B

# %% [markdown]
# ### Top Losers

# %%
# Top Losers

symbol=[]
names=[]
prices=[]
changes=[]
percent_changes=[]
total_volumes=[]
average_volumes=[]
market_caps=[]

 
for i in range(0,41):
    Url = "https://finance.yahoo.com/losers?offset="+str(i)+"&amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;count=100"
    r= requests.get(Url)
    data=r.text
    soup=BeautifulSoup(data)
 
    for item in soup.select('.simpTblRow'):        
        symbol.append(item.select('[aria-label=Symbol]')[0].get_text())
        
        names.append(item.select('[aria-label=Name]')[0].get_text())
        
        prices.append(item.select('[aria-label*=Price]')[0].get_text())
        
        changes.append(item.select('[aria-label=Change]')[0].get_text())
        
        percent_changes.append(item.select('[aria-label="% Change"]')[0].get_text())               
        
        total_volumes.append(item.select('[aria-label*="Volume"]')[0].get_text())
        
        average_volumes.append(item.select('[aria-label*="Avg Vol (3 month)"]')[0].get_text())
        
        market_caps.append(item.select('[aria-label="Market Cap"]')[0].get_text())


top_losers = pd.DataFrame({"symbol": symbol, "names": names, "prices": prices, 
              "change": changes, "percent_changes": percent_changes,  
              "total_volumes": total_volumes,"average_volumes":average_volumes,
              "market_caps": market_caps})

# %%
# Top Losers

symbol=[]
names=[]
prices=[]
changes=[]
percent_changes=[]
total_volumes=[]
average_volumes=[]
market_caps=[]

 
for i in range(0,41):
    Url = "https://finance.yahoo.com/losers?offset="+str(i)+"&amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;amp;count=100"
    r= requests.get(Url)
    data=r.text
    soup=BeautifulSoup(data)
 
    for item in soup.select('.simpTblRow'):        
        symbol.append(item.select('[aria-label=Symbol]')[0].get_text())
        
        names.append(item.select('[aria-label=Name]')[0].get_text())
        
        prices.append(item.select('[aria-label*=Price]')[0].get_text())
        
        changes.append(item.select('[aria-label=Change]')[0].get_text())
        
        percent_changes.append(item.select('[aria-label="% Change"]')[0].get_text())               
        
        total_volumes.append(item.select('[aria-label*="Volume"]')[0].get_text())
        
        average_volumes.append(item.select('[aria-label*="Avg Vol (3 month)"]')[0].get_text())
        
        market_caps.append(item.select('[aria-label="Market Cap"]')[0].get_text())


top_losers_after = pd.DataFrame({"symbol": symbol, "names": names, "prices": prices, 
              "change": changes, "percent_changes": percent_changes,  
              "total_volumes": total_volumes,"average_volumes":average_volumes,
              "market_caps": market_caps})

# %%
top_losers.shape
top_losers.head()
# Out:
# (1025, 8)
#   symbol                      names  prices   change percent_changes  \
# 0  EQUEY    Equatorial Energia S.A.  3.9550  -0.3950          -9.08%
# 1    EQT            EQT Corporation   12.84    -1.15          -8.22%
# 2    ZTO  ZTO Express (Cayman) Inc.   29.59    -2.38          -7.44%
# 3   NKLA         Nikola Corporation   17.88    -1.42          -7.36%
# 4  RLLCF   Rolls-Royce Holdings plc  0.0052  -0.0004          -7.14%
#
#   total_volumes average_volumes market_caps
# 0        36,954           9,198      3.767B
# 1        6.673M          4.474M      3.282B
# 2        8.885M          2.841M     23.195B
# 3       29.975M         27.868M      6.776B
# 4       409,091          3.398M    113.364B

# %% [markdown]
# ## Financial Statement

# %%
from fake_useragent import UserAgent

ua = UserAgent()
user_agent = {'User-agent': ua.random}

# %%
from datetime import datetime
import lxml
from lxml import html
import requests
import numpy as np
import pandas as pd
import random

symbol = 'NIO'
    
url = 'https://finance.yahoo.com/quote/' + symbol + '/balance-sheet?p=' + symbol
    
    
# Set up the request headers that we're going to use, to simulate
# a request by the Chrome browser. Simulating a request from a browser
# is generally good practice when building a scraper
headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
    'Cache-Control': 'max-age=0',
    'Pragma': 'no-cache',
    'Referrer': 'https://google.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36'
}

# Fetch the page that we're going to parse, using the request headers
# defined above
page = requests.get(url, headers)

# Parse the page with LXML, so that we can start doing some XPATH queries
# to extract the data that we want
tree = html.fromstring(page.content)

# Smoke test that we fetched the page by fetching and displaying the H1 element
tree.xpath("//h1/text()")
# Out:
# ['NIO Limited (NIO)']

# %%
table_rows = tree.xpath("//div[contains(@class, 'D(tbr)')]")

# Ensure that some table rows are found; if none are found, then it's possible
# that Yahoo Finance has changed their page layout, or have detected scraping the page.
assert len(table_rows) > 0

parsed_rows = []

for table_row in table_rows:
    parsed_row = []
    el = table_row.xpath("./div")
    
    none_count = 0
    
    for rs in el:
        try:
            (text,) = rs.xpath('.//span/text()[1]')
            parsed_row.append(text)
        except ValueError:
            parsed_row.append(np.NaN)
            none_count += 1

    if (none_count < 4):
        parsed_rows.append(parsed_row)

df = pd.DataFrame(parsed_rows)
df
# Out:
#                                           0           1           2  \
# 0                                 Breakdown  12/31/2019  12/31/2018
# 1                              Total Assets  14,582,029  18,842,552
# 2   Total Liabilities Net Minority Interest  20,859,628  12,021,407
# 3      Total Equity Gross Minority Interest  -6,277,599   6,821,145
# 4                      Total Capitalization     855,112   8,005,053
# 5                       Common Stock Equity  -6,299,686   6,837,041
# 6                 Capital Lease Obligations   2,336,243         NaN
# 7                       Net Tangible Assets  -6,510,023   6,619,909
# 8                           Working Capital  -4,570,850   3,576,246
# 9                          Invested Capital   2,063,168  10,073,905
# 10                      Tangible Book Value  -6,510,023   6,619,909
# 11                               Total Debt  10,699,097   3,236,864
# 12                                 Net Debt   7,500,015     103,017
# ...

# %%
df = pd.DataFrame(parsed_rows)
df = df.set_index(0) # Set the index to the first column: 'Period Ending'.
df = df.transpose() # Transpose the DataFrame, so that our header contains the account names

# Rename the "Breakdown" column to "Date"
cols = list(df.columns)
cols[0] = 'Date'
df = df.set_axis(cols, axis='columns', inplace=False)

df
# Out:
#          Date Total Assets Total Liabilities Net Minority Interest  \
# 1  12/31/2019   14,582,029                              20,859,628
# 2  12/31/2018   18,842,552                              12,021,407
# 3  12/31/2017   10,468,034                              22,059,814
# 4  12/31/2016    1,770,478                               5,686,838
#
#   Total Equity Gross Minority Interest Total Capitalization  \
# 1                           -6,277,599              855,112
# 2                            6,821,145            8,005,053
# 3                          -11,591,780          -10,960,688
# 4                           -3,916,360           -3,867,277
#
#   Common Stock Equity Capital Lease Obligations Net Tangible Assets  \
# 1          -6,299,686                 2,336,243          -6,510,023
# 2           6,837,041                       NaN           6,619,909
# 3         -11,603,089                       NaN         -11,607,546
# ...

# %%
numeric_columns = list(df.columns)[1::] # Take all columns, except the first (which is the 'Date' column)

for column_name in numeric_columns:
    df[column_name] = df[column_name].str.replace(',', '') # Remove the thousands separator
    df[column_name] = df[column_name].astype(np.float64) # Convert the column to float64

df.dtypes
# Out:
# Date                                        object
# Total Assets                               float64
# Total Liabilities Net Minority Interest    float64
# Total Equity Gross Minority Interest       float64
# Total Capitalization                       float64
# Common Stock Equity                        float64
# Capital Lease Obligations                  float64
# Net Tangible Assets                        float64
# Working Capital                            float64
# Invested Capital                           float64
# Tangible Book Value                        float64
# Total Debt                                 float64
# Net Debt                                   float64
# Share Issued                               float64
# Ordinary Shares Number                     float64
# Treasury Shares Number                     float64
# dtype: object

# %% [markdown]
# ### Building Functions Together

# %%
### Put all the functions together

from fake_useragent import UserAgent

ua = UserAgent()
user_agent = {'User-agent': ua.random}

def get_page(url):
    # Set up the request headers that we're going to use, to simulate
    # a request by the Chrome browser. Simulating a request from a browser
    # is generally good practice when building a scraper
    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-US,en;q=0.9',
        'Cache-Control': 'max-age=0',
        'Pragma': 'no-cache',
        'Referrer': 'https://google.com',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36'
    }

    return requests.get(url, headers=user_agent)

def parse_rows(table_rows):
    parsed_rows = []

    for table_row in table_rows:
        parsed_row = []
        el = table_row.xpath("./div")

        none_count = 0

        for rs in el:
            try:
                (text,) = rs.xpath('.//span/text()[1]')
                parsed_row.append(text)
            except ValueError:
                parsed_row.append(np.NaN)
                none_count += 1

        if (none_count < 4):
            parsed_rows.append(parsed_row)
            
    return pd.DataFrame(parsed_rows)

def clean_data(df):
    df = df.set_index(0) # Set the index to the first column: 'Period Ending'.
    df = df.transpose() # Transpose the DataFrame, so that our header contains the account names
    
    # Rename the "Breakdown" column to "Date"
    cols = list(df.columns)
    cols[0] = 'Date'
    df = df.set_axis(cols, axis='columns', inplace=False)
    
    numeric_columns = list(df.columns)[1::] # Take all columns, except the first (which is the 'Date' column)

    for column_index in range(1, len(df.columns)): # Take all columns, except the first (which is the 'Date' column)
        df.iloc[:,column_index] = df.iloc[:,column_index].str.replace(',', '') # Remove the thousands separator
        df.iloc[:,column_index] = df.iloc[:,column_index].astype(np.float64) # Convert the column to float64
        
    return df

def scrape_table(url):
    time.sleep(10+2*random.random()) 
    # Fetch the page that we're going to parse
    page = get_page(url);

    # Parse the page with LXML, so that XPATH queries can be done to extract the data
    tree = html.fromstring(page.content)

    # Fetch all div elements which have class 'D(tbr)'
    table_rows = tree.xpath("//div[contains(@class, 'D(tbr)')]")
    
    # Ensure that some table rows are found; if none are found, then it's possible that 
    # Yahoo Finance has changed their page layout, or have detected.
    assert len(table_rows) > 0
    
    df = parse_rows(table_rows)
    df = clean_data(df)
       
    return df

# %%
df
# Out:
#          Date  Total Assets  Total Liabilities Net Minority Interest  \
# 1  12/31/2019    14582029.0                               20859628.0
# 2  12/31/2018    18842552.0                               12021407.0
# 3  12/31/2017    10468034.0                               22059814.0
# 4  12/31/2016     1770478.0                                5686838.0
#
#    Total Equity Gross Minority Interest  Total Capitalization  \
# 1                            -6277599.0              855112.0
# 2                             6821145.0             8005053.0
# 3                           -11591780.0           -10960688.0
# 4                            -3916360.0            -3867277.0
#
#    Common Stock Equity  Capital Lease Obligations  Net Tangible Assets  \
# 1           -6299686.0                  2336243.0           -6510023.0
# 2            6837041.0                        NaN            6619909.0
# 3          -11603089.0                        NaN          -11607546.0
# ...

# %%
def get_page(url):
    # Set up the request headers that we're going to use, to simulate
    # a request by the Chrome browser. Simulating a request from a browser
    # is generally good practice when building a scraper
    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-US,en;q=0.9',
        'Cache-Control': 'max-age=0',
        'Pragma': 'no-cache',
        'Referrer': 'https://google.com',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36'
    }

    return requests.get(url, headers=user_agent)

def parse_rows(table_rows):
    parsed_rows = []

    for table_row in table_rows:
        parsed_row = []
        el = table_row.xpath("./div")

        none_count = 0

        for rs in el:
            try:
                (text,) = rs.xpath('.//span/text()[1]')
                parsed_row.append(text)
            except ValueError:
                parsed_row.append(np.NaN)
                none_count += 1

        if (none_count < 4):
            parsed_rows.append(parsed_row)
            
    return pd.DataFrame(parsed_rows)

def clean_data(df):
    df = df.set_index(0) # Set the index to the first column: 'Period Ending'.
    df = df.transpose() # Transpose the DataFrame, so that our header contains the account names
    
    # Rename the "Breakdown" column to "Date"
    cols = list(df.columns)
    cols[0] = 'Date'
    df = df.set_axis(cols, axis='columns', inplace=False)
    
    numeric_columns = list(df.columns)[1::] # Take all columns, except the first (which is the 'Date' column)

    for column_index in range(1, len(df.columns)): # Take all columns, except the first (which is the 'Date' column)
        df.iloc[:,column_index] = df.iloc[:,column_index].str.replace(',', '') # Remove the thousands separator
        df.iloc[:,column_index] = df.iloc[:,column_index].astype(np.float64) # Convert the column to float64
        
    return df

def scrape_table(url):
    # Slow down the requests to prevent getting blocked
    time.sleep(5+2*random.random()) 
    
    # Fetch the page
    page = get_page(url);

    # Parse the page with LXML, so that XPATH queries can be done to extract the data 
    tree = html.fromstring(page.content)

    # Fetch all div elements which have class 'D(tbr)'
    table_rows = tree.xpath("//div[contains(@class, 'D(tbr)')]")
    
    # Ensure that some table rows are found; if none are found, then it's possible that 
    # Yahoo Finance has changed their page layout, or have detected.
    assert len(table_rows) > 0
    
    df = parse_rows(table_rows)
    df = clean_data(df)
        
    return df

# %%
scrape_table('https://finance.yahoo.com/quote/' + symbol + '/financials?p=' + symbol)
# Out:
#          Date  Total Revenue  Cost of Revenue  Gross Profit  \
# 1         ttm      7565695.0        8712695.0    -1147000.0
# 2  12/31/2019      7824904.0        9023726.0    -1198822.0
# 3  12/31/2018      4951171.0        5207047.0     -255876.0
# 4  12/31/2017            0.0              NaN           0.0
# 5  12/31/2016            0.0              0.0           0.0
#
#    Operating Expense  Operating Income  \
# 1          8884771.0       -10031771.0
# 2          9880367.0       -11079189.0
# 3          9339732.0        -9595608.0
# 4          4953596.0        -4953596.0
# 5          2602540.0        -2602540.0
#
#    Net Non Operating Interest Income Expense  Other Income Expense  \
# 1                                  -297724.0              -26325.0
# 2                                  -210257.0                1682.0
# 3                                     9741.0              -31068.0
# 4                                      886.0              -60558.0
# ...

# %%
scrape_table('https://finance.yahoo.com/quote/' + symbol + '/cash-flow?p=' + symbol)
# Out:
#          Date  Operating Cash Flow  Investing Cash Flow  Financing Cash Flow  \
# 1         ttm                  NaN                  NaN                  NaN
# 2  12/31/2019           -8721706.0            3382069.0            3094953.0
# 3  12/31/2018           -7911768.0           -7940843.0           11603092.0
# 4  12/31/2017           -4574719.0           -1190273.0           12867334.0
# 5  12/31/2016           -2201564.0             117843.0            2292704.0
#
#    End Cash Position  Income Tax Paid Supplemental Data  \
# 1                NaN                                NaN
# 2           989869.0                            18189.0
# 3          3224387.0                            11157.0
# 4          7530853.0                             1129.0
# 5           596631.0                                0.0
#
#    Interest Paid Supplemental Data  Capital Expenditure  \
# 1                              NaN                  NaN
# ...

# %%
def scrape(symbol):
    

        
    print('Attempting to scrape data for ' + symbol)

        

    df_balance_sheet = scrape_table('https://finance.yahoo.com/quote/' + symbol + '/balance-sheet?p=' + symbol)
    df_balance_sheet = df_balance_sheet.set_index('Date')

    df_income_statement = scrape_table('https://finance.yahoo.com/quote/' + symbol + '/financials?p=' + symbol)
    df_income_statement = df_income_statement.set_index('Date')

    df_cash_flow = scrape_table('https://finance.yahoo.com/quote/' + symbol + '/cash-flow?p=' + symbol)
    df_cash_flow = df_cash_flow.set_index('Date')

    df_joined = df_balance_sheet \
            .join(df_income_statement, on='Date', how='outer', rsuffix=' - Income Statement') \
            .join(df_cash_flow, on='Date', how='outer', rsuffix=' - Cash Flow') \
            .dropna(axis=1, how='all') \
            .reset_index()

    df_joined.insert(1, 'Symbol', symbol)

    return df_joined

# %%
#def scrape_multi(symbols):
#    df_combined = []
#    df_combined.append(scrape(symbol))
#    return pd.concat(df_combined)
df1.append(df2, ignore_index = True)

# %%
def scrape_clean(symbols):
    ddf=pd.concat([scrape(symbol) for symbol in symbols], sort=False)
    ddff = ddf.dropna(subset=['index'])
    #df_clean=ddff.drop(columns = features_drop).groupby("Symbol").first()
    df_clean=ddff.groupby("Symbol").first()
    return df_clean

# %%
def scrape_multi(symbols):
    ddf=pd.DataFrame()
    ddff=ddf.append([scrape(symbol) for symbol in symbols], sort=False)
    #ddff = ddf.dropna(subset=['index'])
    #df_clean=ddff.drop(columns = features_drop).groupby("Symbol").first()
    #df_clean=ddf.groupby("Symbol").first()
    return ddff

# %%
symbols = ["FB", "AMZN"]
df_final = scrape_clean(symbols)
# Out:
# Attempting to scrape data for FB
# Attempting to scrape data for AMZN

# %%
df_final
# Out:
#              index        Date  Total Assets  \
# Symbol
# AMZN    12/31/2019  12/31/2019   225248000.0
# FB      12/31/2019  12/31/2019   133376000.0
#
#         Total Liabilities Net Minority Interest  \
# Symbol
# AMZN                                163188000.0
# FB                                   32322000.0
#
#         Total Equity Gross Minority Interest  Total Capitalization  \
# Symbol
# AMZN                              62060000.0            85474000.0
# FB                               101054000.0           101054000.0
#
#         Common Stock Equity  Capital Lease Obligations  Net Tangible Assets  \
# Symbol
# AMZN             62060000.0                 39791000.0           43257000.0
# FB              101054000.0                 10324000.0           81445000.0
#
#         Working Capital  ...  End Cash Position  \
# Symbol                   ...
# AMZN          8522000.0  ...         36410000.0
# FB           51172000.0  ...         19279000.0
#
# ...

# %% [markdown]
# ### Trial Set

# %%
symbols = stocks_90
df_90 = scrape_clean(symbols)
# Out:
# Attempting to scrape data for ABEV
# Attempting to scrape data for DKNG
# Attempting to scrape data for SPCE
# Attempting to scrape data for NKLA
# Attempting to scrape data for OXY
# Attempting to scrape data for VALE
# Attempting to scrape data for WPX
# Attempting to scrape data for T
# Attempting to scrape data for MU
# Attempting to scrape data for DVN
# Attempting to scrape data for NOK
# Attempting to scrape data for UAL
# Attempting to scrape data for PBR
# Attempting to scrape data for WKHS
# Attempting to scrape data for AAPL
# Attempting to scrape data for SRNE
# Attempting to scrape data for GE
# Attempting to scrape data for AMD
# Attempting to scrape data for TSLA
# Attempting to scrape data for AAL
# Attempting to scrape data for PTON
# Attempting to scrape data for BAC
# Attempting to scrape data for F
# Attempting to scrape data for WFC
# Attempting to scrape data for ABEV
# Attempting to scrape data for DKNG
# Attempting to scrape data for SPCE
# ...

# %%
stocks_30=list(most_active_after['symbol'])[21:30]

# %%
symbols = stocks_30
df_30 = (scrape_clean(symbols))
# Out:
# Attempting to scrape data for NOK
# Attempting to scrape data for SIRI
# Attempting to scrape data for ABEV
# Attempting to scrape data for BABA
# Attempting to scrape data for AAPL
# Attempting to scrape data for NKLA
# Attempting to scrape data for GE
# Attempting to scrape data for AAL
# Attempting to scrape data for MU

# %%
df_30
# Out:
#               Date  Total Assets  Total Liabilities Net Minority Interest  \
# Symbol
# AAL     12/31/2019  5.999500e+07                               60113000.0
# AAPL     9/30/2019  3.385160e+08                              248028000.0
# ABEV    12/31/2019  1.017429e+08                               39186900.0
# BABA     3/31/2020  1.312985e+09                              442437000.0
# GE      12/31/2019  2.660480e+08                              236187000.0
# MU       8/31/2019  4.888700e+07                               12117000.0
# NOK     12/31/2019  3.912800e+07                               23727000.0
# SIRI    12/31/2019  1.114900e+07                               11885000.0
#
#         Total Equity Gross Minority Interest  Total Capitalization  \
# Symbol
# AAL                                -118000.0            21336000.0
# AAPL                              90488000.0           182295000.0
# ABEV                              62556000.0            61975800.0
# ...

# %%
df_10=df_final

# %%
len(stocks_90)
# Out:
# 90

# %%
stocks_20=list(most_active_after['symbol'])[11:20]

# %%
stocks_20
# Out:
# ['NCLH', 'WFC', 'BA', 'T', 'UAL', 'DDOG', 'SRNE', 'PBR', 'VALE']

# %%
len(set(top_gainers_after["symbol"]))
# Out:
# 65

# %%
stocks_100[0:]
# Out:
# ['NIO',
#  'AAPL',
#  'NKLA',
#  'GE',
#  'AAL',
#  'MU',
#  'F',
#  'AMD',
#  'TSLA',
#  'BAC',
#  'CCL',
#  'NCLH',
#  'WFC',
#  'BA',
#  'T',
#  'UAL',
#  'DDOG',
#  'SRNE',
#  'PBR',
#  'VALE',
#  'MSFT',
#  'NOK',
#  'SIRI',
#  'ABEV',
#  'BABA',
#  'AAPL',
#  'NKLA',
#  'GE',
#  'AAL',
#  'MU',
#  'F',
#  'AMD',
#  'TSLA',
#  'BAC',
#  'CCL',
#  'NCLH',
#  'WFC',
#  'BA',
#  'T',
#  'UAL',
#  'DDOG',
#  'SRNE',
#  'PBR',
#  'VALE',
#  'MSFT',
#  'NOK',
#  'SIRI',
#  'ABEV',
#  'BABA',
#  'MRO',
#  'NKLA',
#  'GE',
#  'AAL',
#  'MU',
#  'F',
#  'AMD',
#  'TSLA',
#  'BAC',
#  'CCL',
#  'NCLH',
#  'WFC',
#  'BA',
#  'T',
#  'UAL',
#  'DDOG',
#  'SRNE',
#  'PBR',
#  'VALE',
#  'MSFT',
#  'NOK',
#  'SIRI',
#  'ABEV',
#  'BABA',
#  'MRO',
#  'PLUG',
#  'GE',
#  'AAL',
#  'MU',
#  'F',
#  'AMD',
#  'TSLA',
#  'BAC',
#  'CCL',
#  'NCLH',
#  'WFC',
#  'BA',
#  'T',
#  'UAL',
#  'DDOG',
#  'SRNE',
#  'PBR',
#  'VALE',
#  'MSFT',
#  'NOK',
#  'SIRI',
#  'ABEV',
#  'BABA',
#  'MRO',
# ...

# %%
pd.DataFrame(df_combined).shape
# Out:
# (24, 64)

# %%
features_raw = list(pd.DataFrame(df_combined).columns)

# %%
features = ['Symbol','Date','Total Assets', 'Total Liabilities Net Minority Interest',
            'Total Equity Gross Minority Interest', 
                   'Total Capitalization','Common Stock Equity','Invested Capital', 'Tangible Book Value', 
                   'Total Revenue', 'Cost of Revenue', 'Gross Profit', 'Operating Expense','Operating Income', 
            'Diluted EPS','Diluted Average Shares', 'Total Expenses','Normalized EBITDA','Operating Cash Flow',
                   'Investing Cash Flow', 'Financing Cash Flow', 'End Cash Position']

# %%
(pd.DataFrame(df_combined)[features]).shape
# Out:
# (24, 22)

# %%
from collections import Counter 

features_drop=list((Counter(features_raw) - Counter(features)).elements())

# %%
features_drop
# Out:
# ['index',
#  'Capital Lease Obligations',
#  'Net Tangible Assets',
#  'Working Capital',
#  'Total Debt',
#  'Share Issued',
#  'Ordinary Shares Number',
#  'Treasury Shares Number',
#  'Net Non Operating Interest Income Expense',
#  'Other Income Expense',
#  'Pretax Income',
#  'Tax Provision',
#  'Net Income Common Stockholders',
#  'Average Dilution Earnings',
#  'Diluted NI Available to Com Stockholders',
#  'Basic EPS',
#  'Basic Average Shares',
#  'Total Operating Income as Reported',
#  'Net Income from Continuing & Discontinued Operation',
#  'Normalized Income',
#  'Interest Income',
#  'Interest Expense',
#  'Net Interest Income',
#  'EBIT',
#  'Reconciled Cost of Revenue',
#  'Reconciled Depreciation',
#  'Net Income from Continuing Operation Net Minority Interest',
#  'Total Unusual Items Excluding Goodwill',
#  'Total Unusual Items',
#  'Tax Rate for Calcs',
#  'Tax Effect of Unusual Items',
#  'Income Tax Paid Supplemental Data',
# ...

# %%
ddf=pd.DataFrame(df_combined)

# %%
ddff = ddf.dropna(subset=['index'])

# %%
ddff.drop(columns = features_drop).groupby("Symbol").first()
# Out:
#               Date  Total Assets  Total Liabilities Net Minority Interest  \
# Symbol
# AAPL     9/30/2019   338516000.0                              248028000.0
# AMZN    12/31/2019   225248000.0                              163188000.0
# FB      12/31/2019   133376000.0                               32322000.0
# GOOG    12/31/2019   275909000.0                               74467000.0
# NFLX    12/31/2019    33975712.0                               26393555.0
#
#         Total Equity Gross Minority Interest  Total Capitalization  \
# Symbol
# AAPL                              90488000.0           182295000.0
# AMZN                              62060000.0            85474000.0
# FB                               101054000.0           101054000.0
# GOOG                             201442000.0           205400000.0
# NFLX                               7582157.0            22341417.0
#
#         Common Stock Equity  Invested Capital  Tangible Book Value  \
# Symbol
# ...

# %%
def scrape_clean(symbols):
    ddf=pd.concat([scrape(symbol) for symbol in symbols], sort=False)
    ddff = ddf.dropna(subset=['index'])
    df_clean=ddff.drop(columns = features_drop).groupby("Symbol").first()
    return df_clean

# %%
symbols = ["FB", "AMZN"]
df_final_test = scrape_multi(symbols)
# Out:
# Attempting to scrape data for FB
# Attempting to scrape data for AMZN

# %%
df_final.head()
# Out:
#               Date  Total Assets  Total Liabilities Net Minority Interest  \
# Symbol
# AMZN    12/31/2019   225248000.0                              163188000.0
# FB      12/31/2019   133376000.0                               32322000.0
#
#         Total Equity Gross Minority Interest  Total Capitalization  \
# Symbol
# AMZN                              62060000.0            85474000.0
# FB                               101054000.0           101054000.0
#
#         Common Stock Equity  Invested Capital  Tangible Book Value  \
# Symbol
# AMZN             62060000.0        85474000.0           43257000.0
# FB              101054000.0       101331000.0           81445000.0
#
#         Total Revenue  Cost of Revenue  ...  Operating Expense  \
# Symbol                                  ...
# AMZN      280522000.0      205768000.0  ...         60213000.0
# FB         70697000.0       12770000.0  ...         33941000.0
#
# ...

# %%
stocks = list(most_active['symbol'])
stocks_after= list(most_active_after['symbol'])

# %%
#Two days of most active lists only have 77 duplicates
import collections
print([item for item, count in collections.Counter((stocks+stocks_after)).items() if count > 1])
# Out:
# ['NIO', 'AAPL', 'SRNE', 'GE', 'AMD', 'TSLA', 'AAL', 'PTON', 'BAC', 'F', 'WFC', 'ABEV', 'DKNG', 'SPCE', 'NKLA', 'OXY', 'VALE', 'WPX', 'T', 'MU', 'DVN', 'NOK', 'UAL', 'PBR', 'WKHS', 'CZR', 'MRO', 'CCL', 'PCG', 'ITUB', 'BBD', 'C', 'BYND', 'MSFT', 'PLUG', 'BA', 'XOM', 'FB', 'SIRI', 'INTC', 'UBER', 'CSCO', 'SNAP', 'SLB', 'CLF', 'NVDA', 'ZM', 'ZNGA', 'BP', 'DAL', 'SPWR', 'NCLH', 'FCX', 'TWTR', 'HAL', 'NBL', 'APA', 'KSS', 'NLY', 'JPM', 'PFE', 'MGM', 'VIPS', 'GOLD', 'DDOG', 'BABA', 'ET', 'CMCSA', 'DUK', 'KMI', 'MRNA', 'OPK', 'WDC', 'MS', 'INFY', 'PENN', 'COTY']

# %%
stocks_10=stocks[0:10]

# %%
print(stocks_10)
# Out:
# ['NIO', 'AAPL', 'SRNE', 'GE', 'AMD', 'TSLA', 'AAL', 'PTON', 'BAC', 'F']

# %%
# Trying to slow down the request

import time


for i, symbol in enumerate(stocks_10):
    symbols = stocks_10
    
       
    if (i+1 % 2 == 0):
        time.sleep(30)
    
    scrape_multi(symbols)
# Out:
# Attempting to scrape data for NIO
# Attempting to scrape data for AAPL
# Attempting to scrape data for SRNE
# Attempting to scrape data for GE
# Attempting to scrape data for AMD
# Attempting to scrape data for TSLA
# Attempting to scrape data for AAL
# Attempting to scrape data for PTON
# Attempting to scrape data for BAC
# Attempting to scrape data for F
# Attempting to scrape data for NIO
# Attempting to scrape data for AAPL
# Attempting to scrape data for SRNE
# Attempting to scrape data for GE
# Attempting to scrape data for AMD
# Attempting to scrape data for TSLA
# Attempting to scrape data for AAL
# Attempting to scrape data for PTON
# Attempting to scrape data for BAC
# Attempting to scrape data for F
# Attempting to scrape data for NIO
# Attempting to scrape data for AAPL
# Attempting to scrape data for SRNE
# Attempting to scrape data for GE
# ---------------------------------------------------------------------------
# ...

# %%
pd.DataFrame(df_combined).iloc[:,30:40]
# Out:
#    Diluted EPS  Basic Average Shares  Diluted Average Shares  \
# 0       0.0064             2854000.0               2876000.0
# 1       0.0076             2890000.0               2921000.0
# 2       0.0054             2901000.0               2956000.0
# 3       0.0035             2863000.0               2925000.0
# 4          NaN                   NaN                     NaN
# 0       0.0230              494000.0                504000.0
# 1       0.0201              487000.0                500000.0
# 2       0.0062              480000.0                493000.0
# 3       0.0049              474000.0                484000.0
# 4          NaN                   NaN                     NaN
# 0       0.0030            18471336.0              18595652.0
# 1       0.0030            19821508.0              20000436.0
# 2       0.0023            20868968.0              21006768.0
# 3          NaN                   NaN                     NaN
# ...

# %%
pd.DataFrame(df_combined).iloc[:,33]
# Out:
# 0    23986000.0
# 1    24913000.0
# 2    20203000.0
# 3    12427000.0
# 4    26562000.0
# 0    14541000.0
# 1    12421000.0
# 2     4106000.0
# 3     4186000.0
# 4    16869000.0
# 0    63930000.0
# 1    70898000.0
# 2    61344000.0
# 3    67138000.0
# 0     2604254.0
# 1     1605226.0
# 2      838679.0
# 3      379793.0
# 4     3754935.0
# 0    34231000.0
# 1    26321000.0
# 2    26146000.0
# 3    23716000.0
# 4    32803000.0
# Name: Total Operating Income as Reported, dtype: float64

# %%
most_active_after
# Out:
#      symbol                         names  prices   change percent_changes  \
# 0       NIO                   NIO Limited   21.22    +0.37          +1.77%
# 1      AAPL                    Apple Inc.  115.81    +1.72          +1.51%
# 2      NKLA            Nikola Corporation   20.48    +2.60         +14.54%
# 3        GE      General Electric Company    6.23    +0.11          +1.80%
# 4       AAL  American Airlines Group Inc.   12.29    +0.04          +0.33%
# ...     ...                           ...     ...      ...             ...
# 1020   PENN    Penn National Gaming, Inc.   72.70    +3.29          +4.74%
# 1021   COTY                     Coty Inc.  2.7000  +0.0500          +1.89%
# 1022    WPX              WPX Energy, Inc.  4.9000  -0.0900          -1.80%
# 1023    CLF         Cleveland-Cliffs Inc.    6.42    -0.15          -2.28%
# 1024    AUY              Yamana Gold Inc.    5.68    -0.02          -0.35%
#
#      total_volumes average_volumes market_caps
# ...

# %% [markdown]
# ## API Tiingo
#
# Use Tiigo's API to extract stock prices

# %%
import requests

headers = {
        'Content-Type': 'application/json',
        'Authorization' : 'Token 774d4f1e77734e566b39f6fd21c2c0458edd8b66'
        }

requestResponse = requests.get("https://api.tiingo.com/tiingo/daily/aapl/prices?startDate=2019-09-30&startDate=2019-09-30&endDate=2019-09-30&columns=high,low,open,close,volume&token=774d4f1e77734e566b39f6fd21c2c0458edd8b66", headers=headers)
print(requestResponse.json())
# Out:
# [{'date': '2019-09-30T00:00:00.000Z', 'high': 224.58, 'low': 220.79, 'open': 220.9, 'close': 223.97, 'volume': 26318583}]

# %%
pd.DataFrame(result)
# Out:
#                        date    high     low   open   close
# 0  2019-09-30T00:00:00.000Z  224.58  220.79  220.9  223.97

# %%
import requests
price=[]
headers = {
        'Content-Type': 'application/json',
        'Authorization' : 'Token 774d4f1e77734e566b39f6fd21c2c0458edd8b66'
        }

requestResponse = requests.get("https://api.tiingo.com/tiingo/daily/aapl/prices?startDate=2019-09-30&startDate=2019-09-30&endDate=2019-09-30&columns=high,low,open,close,volume&token=774d4f1e77734e566b39f6fd21c2c0458edd8b66", headers=headers)
price.append(requestResponse.json()[0])

# %%
price
# Out:
# [{'date': '2019-09-30T00:00:00.000Z',
#   'high': 224.58,
#   'low': 220.79,
#   'open': 220.9,
#   'close': 223.97,
#   'volume': 26318583}]

# %%
price[0]["high"]
# Out:
# 224.58

# %% [markdown]
# ## Stock Symbols

# %%
stock_symobols = pd.read_csv('companylist.csv') # Download Symbol list from NASDAQ

# %%
stock_symobols.dropna()
# Out:
# Empty DataFrame
# Columns: [Symbol, Name, LastSale, MarketCap, IPOyear, Sector, industry, Summary Quote, Unnamed: 8]
# Index: []

# %%
stock_symobols.drop(columns="Summary Quote")
# Out:
#      Symbol                                    Name  LastSale MarketCap  \
# 0       TXG                      10x Genomics, Inc.   126.470    $13.2B
# 1        YI                               111, Inc.     6.320  $520.51M
# 2       PIH  1347 Property Insurance Holdings, Inc.     3.760   $18.57M
# 3     PIHPP  1347 Property Insurance Holdings, Inc.    24.690       NaN
# 4      TURN                180 Degree Capital Corp.     1.890   $58.82M
# ...     ...                                     ...       ...       ...
# 3773     ZS                           Zscaler, Inc.   144.295   $19.18B
# 3774   ZUMZ                             Zumiez Inc.    27.770  $706.61M
# 3775   ZYNE           Zynerba Pharmaceuticals, Inc.     3.380   $98.88M
# 3776   ZYXI                             Zynex, Inc.    18.240  $633.03M
# 3777   ZNGA                              Zynga Inc.     9.490   $10.21B
#
#       IPOyear             Sector  \
# 0      2019.0      Capital Goods
# ...

# %%
stock_symobols.sort_values("IPOyear")
# Out:
#      Symbol                          Name  LastSale  MarketCap  IPOyear  \
# 265    AMAT       Applied Materials, Inc.     60.65    $55.39B   1972.0
# 768    COKE  Coca-Cola Consolidated, Inc.    239.31     $2.24B   1972.0
# 3660   WDFC                 WD-40 Company    187.40     $2.56B   1973.0
# 2074   KLAC              KLA Corporation     198.98    $30.86B   1980.0
# 262    AAPL                    Apple Inc.    116.79  $2024.83B   1980.0
# ...     ...                           ...       ...        ...      ...
# 3764  ZIONP     Zions Bancorporation N.A.     24.52        NaN      NaN
# 3765   ZIOP         ZIOPHARM Oncology Inc      2.62   $561.08M      NaN
# 3766   ZIXI               Zix Corporation      5.96   $339.92M      NaN
# 3772    ZVO                    Zovio Inc.      4.05   $130.16M      NaN
# 3776   ZYXI                   Zynex, Inc.     18.24   $633.03M      NaN
#
#                      Sector  \
# 265              Technology
# 768   Consumer Non-Durables
# ...

# %%
stock_symobols.drop(columns=["Summary Quote","Unnamed: 8"], inplace=True)

# %%
stock_symobols.dropna(inplace=True)

# %%
stock_symobols.sort_values("MarketCap")
# Out:
#      Symbol                           Name  LastSale MarketCap  IPOyear  \
# 123    AKRO       Akero Therapeutics, Inc.     29.18    $1.01B   2019.0
# 486    BTAI     BioXcel Therapeutics, Inc.     44.97    $1.01B   2018.0
# 73     ADVM  Adverum Biotechnologies, Inc.     10.52    $1.02B   2014.0
# 3007   SAFT   Safety Insurance Group, Inc.     67.68    $1.02B   2002.0
# 668    CERS              Cerus Corporation      6.16    $1.02B   1997.0
# ...     ...                            ...       ...       ...      ...
# 1078   PLUS                     ePlus inc.     73.23  $992.52M   1996.0
# 3768   ZGNX                  Zogenix, Inc.     17.92  $993.63M   2010.0
# 1087   ESPR    Esperion Therapeutics, Inc.     35.76  $995.04M   2013.0
# 3401   TBIO            Translate Bio, Inc.     13.45  $998.58M   2018.0
# 2969   RYTM   Rhythm Pharmaceuticals, Inc.     22.65  $999.29M   2017.0
#
#            Sector                                           industry
# ...

# %%
stock_symobols.sort_values("Symbol")
# Out:
#      Symbol                            Name  LastSale  MarketCap  IPOyear  \
# 267    AAOI   Applied Optoelectronics, Inc.    11.220   $255.52M   2013.0
# 262    AAPL                      Apple Inc.   116.790  $2024.83B   1980.0
# 214    ABCB                  Ameris Bancorp    23.030      $1.6B   1994.0
# 147    ABTX     Allegiance Bancshares, Inc.    23.590   $481.98M   2015.0
# 28     ACAD     ACADIA Pharmaceuticals Inc.    42.140     $6.69B   1985.0
# ...     ...                             ...       ...        ...      ...
# 3756   ZNTL  Zentalis Pharmaceuticals, Inc.    31.710     $1.27B   2020.0
# 3773     ZS                   Zscaler, Inc.   144.295    $19.18B   2018.0
# 3771   ZSAN       Zosano Pharma Corporation     0.700    $66.94M   2015.0
# 3774   ZUMZ                     Zumiez Inc.    27.770   $706.61M   2005.0
# 3775   ZYNE   Zynerba Pharmaceuticals, Inc.     3.380    $98.88M   2015.0
#
#                  Sector                        industry
# ...

# %%
stock_symobols.groupby("Sector").count() 
# Top 4 Sectors are "Healthcare","Technology","Finance" and "Consumer Services"
# Out:
#                        Symbol  Name  LastSale  MarketCap  IPOyear  industry
# Sector
# Basic Industries           29    29        29         29       29        29
# Capital Goods              75    75        75         75       75        75
# Consumer Durables          31    31        31         31       31        31
# Consumer Non-Durables      47    47        47         47       47        47
# Consumer Services         158   158       158        158      158       158
# Energy                     25    25        25         25       25        25
# Finance                   221   221       221        221      221       221
# Health Care               547   547       547        547      547       547
# Miscellaneous              50    50        50         50       50        50
# Public Utilities           25    25        25         25       25        25
# Technology                299   299       299        299      299       299
# ...

# %%
stock_t=stock_symobols[stock_symobols["Sector"] == "Technology"]

# %%
stock_h=stock_symobols[stock_symobols["Sector"] == "Health Care"]
stock_f=stock_symobols[stock_symobols["Sector"] == "Finance"]
stock_c=stock_symobols[stock_symobols["Sector"] == "Consumer Services"]

# %%
stock_select = pd.concat([stock_t,stock_h,stock_f,stock_c], verify_integrity=True)

# %%
stock_select
# Out:
#      Symbol                         Name  LastSale MarketCap  IPOyear  \
# 10     VNET         21Vianet Group, Inc.    23.830     $2.7B   2011.0
# 11     TWOU                     2U, Inc.    34.840    $2.24B   2014.0
# 14     JOBS                  51job, Inc.    75.030    $5.04B   2004.0
# 24     ACIA  Acacia Communications, Inc.    67.370    $2.83B   2016.0
# 47     ACMR           ACM Research, Inc.    75.380    $1.36B   2017.0
# ...     ...                          ...       ...       ...      ...
# 3692   WING                Wingstop Inc.   140.340    $4.15B   2015.0
# 3720   WYNN        Wynn Resorts, Limited    72.070    $7.77B   2002.0
# 3751     YJ                   Yunji Inc.     1.830  $388.54M   2019.0
# 3757   ZCMD               ZHONGCHAO INC.     1.715   $40.41M   2020.0
# 3774   ZUMZ                  Zumiez Inc.    27.770  $706.61M   2005.0
#
#                  Sector                                         industry
# ...

# %%
stocks=list(stock_select["Symbol"])

# %%
len(stocks)
# Out:
# 1225

# %%
stocks[0:10]
# Out:
# ['VNET', 'TWOU', 'JOBS', 'ACIA', 'ACMR', 'ADBE', 'AGMH', 'API', 'AIRG', 'KERN']

# %% [markdown]
# # Dataset Production

# %% [markdown]
# ## Automate Production

# %%
symbols = stocks[0:10] # RENAME!!!

final_10f = scrape_clean(symbols)
# Out:
# Attempting to scrape data for VNET
# Attempting to scrape data for TWOU
# Attempting to scrape data for JOBS
# Attempting to scrape data for ACIA
# Attempting to scrape data for ACMR
# Attempting to scrape data for ADBE
# Attempting to scrape data for AGMH
# Attempting to scrape data for API
# Attempting to scrape data for AIRG
# Attempting to scrape data for KERN

# %%
final_710 = scrape_clean(stocks[700:710])

time.sleep(25)

final_720 = scrape_clean(stocks[710:720])

time.sleep(30)

final_730 = scrape_clean(stocks[720:730])

time.sleep(20)

final_740 = scrape_clean(stocks[730:740])

time.sleep(30)

final_750 = scrape_clean(stocks[740:750])

time.sleep(25)

final_760 = scrape_clean(stocks[750:760])

time.sleep(30)

final_770 = scrape_clean(stocks[760:770])

time.sleep(20)

final_780 = scrape_clean(stocks[770:780])

time.sleep(30)

final_790 = scrape_clean(stocks[780:790])

time.sleep(25)

final_800 = scrape_clean(stocks[790:800])
# Out:
# Attempting to scrape data for PHAT
# Attempting to scrape data for PAHC
# Attempting to scrape data for PLRX
# Attempting to scrape data for PLXP
# Attempting to scrape data for PMVP
# Attempting to scrape data for PYPD
# Attempting to scrape data for PSTX
# Attempting to scrape data for PPD
# Attempting to scrape data for PRAH
# Attempting to scrape data for DTIL
# Attempting to scrape data for PRLD
# Attempting to scrape data for PRVL
# Attempting to scrape data for PROG
# Attempting to scrape data for PGNY
# Attempting to scrape data for PRQR
# Attempting to scrape data for PTGX
# Attempting to scrape data for TARA
# Attempting to scrape data for PTI
# Attempting to scrape data for PRVB
# Attempting to scrape data for PTCT
# Attempting to scrape data for PULM
# Attempting to scrape data for PLSE
# Attempting to scrape data for QLGN
# Attempting to scrape data for QTNT
# Attempting to scrape data for RDUS
# Attempting to scrape data for RAPT
# Attempting to scrape data for RETA
# ...

# %%
final_810 = scrape_clean(stocks[800:810])

time.sleep(25)

final_820 = scrape_clean(stocks[810:820])

time.sleep(30)

final_830 = scrape_clean(stocks[820:830])

time.sleep(20)

final_840 = scrape_clean(stocks[830:840])

time.sleep(30)

final_850 = scrape_clean(stocks[840:850])

time.sleep(25)

final_860 = scrape_clean(stocks[850:860])

time.sleep(30)

final_870 = scrape_clean(stocks[860:870])

time.sleep(20)

final_880 = scrape_clean(stocks[870:880])

time.sleep(30)

final_890 = scrape_clean(stocks[880:890])

time.sleep(25)

final_900 = scrape_clean(stocks[890:900])

time.sleep(30)

final_910 = scrape_clean(stocks[900:910])

time.sleep(25)

final_920 = scrape_clean(stocks[910:920])

time.sleep(30)

final_930 = scrape_clean(stocks[920:930])

time.sleep(20)

final_940 = scrape_clean(stocks[930:940])

time.sleep(30)

final_950 = scrape_clean(stocks[940:950])

time.sleep(25)

final_960 = scrape_clean(stocks[950:960])

time.sleep(30)

final_970 = scrape_clean(stocks[960:970])

time.sleep(20)

final_980 = scrape_clean(stocks[970:980])

time.sleep(30)

final_990 = scrape_clean(stocks[980:990])

time.sleep(25)

final_1000 = scrape_clean(stocks[990:1000])
# Out:
# Attempting to scrape data for TMDX
# Attempting to scrape data for TRVN
# Attempting to scrape data for TRVI
# Attempting to scrape data for TCDA
# Attempting to scrape data for TRIB
# Attempting to scrape data for TPTX
# Attempting to scrape data for TWST
# Attempting to scrape data for UFPT
# Attempting to scrape data for RARE
# Attempting to scrape data for QURE
# Attempting to scrape data for UTHR
# Attempting to scrape data for UBX
# Attempting to scrape data for UMRX
# Attempting to scrape data for URGN
# Attempting to scrape data for UROV
# Attempting to scrape data for VCNX
# Attempting to scrape data for VNDA
# Attempting to scrape data for VBLT
# Attempting to scrape data for PCVX
# Attempting to scrape data for VERO
# Attempting to scrape data for VCYT
# Attempting to scrape data for VSTM
# Attempting to scrape data for VRNA
# Attempting to scrape data for VRCA
# Attempting to scrape data for VRTX
# Attempting to scrape data for VIE
# Attempting to scrape data for VKTX
# ...

# %%
final_1000p = scrape_clean(stocks[1000:])
# Out:
# Attempting to scrape data for PMBC
# Attempting to scrape data for PLMR
# Attempting to scrape data for PCB
# Attempting to scrape data for PCSB
# Attempting to scrape data for PDLB
# Attempting to scrape data for PBFS
# Attempting to scrape data for PRAA
# Attempting to scrape data for PFBI
# Attempting to scrape data for PFG
# Attempting to scrape data for PFHD
# Attempting to scrape data for PTAC
# Attempting to scrape data for PVBC
# Attempting to scrape data for PHCF
# Attempting to scrape data for PUYI
# Attempting to scrape data for QK
# Attempting to scrape data for RNDB
# Attempting to scrape data for RBB
# Attempting to scrape data for RRBI
# Attempting to scrape data for RDFN
# Attempting to scrape data for RBCAA
# Attempting to scrape data for RBKB
# Attempting to scrape data for RMBI
# Attempting to scrape data for ROCH
# Attempting to scrape data for SAFT
# Attempting to scrape data for SAMA
# Attempting to scrape data for SEIC
# Attempting to scrape data for AIHS
# ...

# %% [markdown]
# ## Stich Together

# %%
final_10f.columns
# Out:
# Index(['index', 'Date', 'Total Assets',
#        'Total Liabilities Net Minority Interest',
#        'Total Equity Gross Minority Interest', 'Total Capitalization',
#        'Common Stock Equity', 'Capital Lease Obligations',
#        'Net Tangible Assets', 'Working Capital', 'Invested Capital',
#        'Tangible Book Value', 'Total Debt', 'Net Debt', 'Share Issued',
#        'Ordinary Shares Number', 'Total Revenue', 'Cost of Revenue',
#        'Gross Profit', 'Operating Expense', 'Operating Income',
#        'Net Non Operating Interest Income Expense', 'Other Income Expense',
#        'Pretax Income', 'Tax Provision',
#        'Earnings from Equity Interest Net of Tax',
#        'Net Income Common Stockholders',
#        'Diluted NI Available to Com Stockholders', 'Basic EPS', 'Diluted EPS',
#        'Basic Average Shares', 'Diluted Average Shares',
#        'Total Operating Income as Reported', 'Total Expenses',
#        'Net Income from Continuing & Discontinued Operation',
# ...

# %%
# Production Log

### final_10 (less columns),final_30,final_60,final_100, final_130

### final_140, 145, 150, 160, 170, 180, 190, 200

### 210,220,230,240,250,260,270,280,290,300

### 310, 320, 330,340,350,360,370,380,390,400

### 410 - 500

### 5-6

### 6-7

### 7-8

### 8-9

### 9-1000
### 1000p

# %%
pd_list = [final_10, final_30, final_60, final_100, 
           final_130, final_140, final_145, final_150, final_160, final_170, final_180, final_190, final_200,
           final_210, final_220, final_230, final_240, final_250, final_260, final_270, final_280, final_290, final_300,
           final_310, final_320, final_330, final_340, final_350, final_360, final_370, final_380, final_390, final_400,
           final_410, final_420, final_430, final_440, final_450, final_460, final_470, final_480, final_490, final_500,
           final_510, final_520, final_530, final_540, final_550, final_560, final_570, final_580, final_590, final_600,
           final_610, final_620, final_630, final_640, final_650, final_660, final_670, final_680, final_690, final_700,
           final_710, final_720, final_730, final_740, final_750, final_760, final_770, final_780, final_790, final_800,
           final_810, final_820, final_830, final_840, final_850, final_860, final_870, final_880, final_890, final_900,
           final_910, final_920, final_930, final_940, final_950, final_960, final_970, final_980, final_990, final_1000,
           final_1000p]

df_raw = pd.concat(pd_list, sort=False)

# %%
# Save to a CSV file
# 1206 companies in NASDAQ from 4 sectors: Technology, Health Care, Finance and Consumer Services

df_raw.to_csv('financial_statement_raw.csv')
